# %%
from common import *

# %%
df_train = pd.read_csv(CACHE_DIR+'/train_with_titles_en.csv')

# %%
df_train.head()
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
#
#                                                title  label_group  \
# 0                          Paper Bag Victoria Secret    249114794
# 1  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...   2937985045
# 2        Maling TTS Canned Pork Luncheon Meat 397 gr   2395904891
# 3  Daster Batik Lengan pendek - Motif Acak / Camp...   4093212188
# 4                  Nescafe \xc3\x89clair Latte 220ml   3648931069
#
#                                            titles_en
# 0                      ♪ Paper Bag Victoria Secret ♪
# ...

# %%
df_train.loc[df_train.title == 'TOPI BAYI TOPI BAYI LAKI LAKI TOPI BAYI PEREMPUAN topi bayi newborn TOPI BAYI LUCU topi bayi laki']
# Out:
#              posting_id                                 image  \
# 26999  train_2679050144  c9f5319bf3c69e16f97aedcc2582aa7d.jpg
#
#             image_phash                                              title  \
# 26999  ab2d98e0c721bfd0  TOPI BAYI TOPI BAYI LAKI LAKI TOPI BAYI PEREMP...
#
#        label_group                                          titles_en
# 26999   2843587555  ♪ To put in a baby ♪ ♪ baby, baby, baby ♪ ♪ ba...

# %%
df_train.columns
# Out:
# Index(['posting_id', 'image', 'image_phash', 'title', 'label_group',
#        'titles_en'],
#       dtype='object')

# %%
df_train.loc[df_train.title == 'TOPI BAYI TOPI BAYI LAKI LAKI TOPI BAYI PEREMPUAN topi bayi newborn TOPI BAYI LUCU topi bayi laki', 'titles_en'] = 'To put in a baby, baby, baby, baby'

# %%
titles_en_li = df_train.titles_en.values
titles = df_train.title.values

# %%
titles_en_li[0]
# Out:
# '♪ Paper Bag Victoria Secret ♪'

# %%
max_len = 0
min_len = 10000
for t in titles:
    li = t.split(' ')
#     print(l)
    l = len(li)
    if l == 1:
        print(t)
    if l > 60:
        print(t)
    if l < min_len:
        min_len = l
    if l > max_len:
        max_len = l
print(min_len, max_len)
# Out:
# Overall
# Caviplex
# Merries
# Nebula
# fullo
# SIGNATURE
# Freshcare
# Sepatupria/sepatualphabounce/sepaturuning
# Stimulant
# Mayonnaise
# Blacksoap
# Maycreate
# HERBADIABS
# KACAMATA
# Herbadiabs
# MASKYOURNEEDS
# tas/ransel/pria/cowok/anak/sekolah/sd/smp/sma/backpack/carrier/kerja/kantor/formal/murah
# BEAUSLIM
# Glulagen
# PENANCE
# STIMULANT
# Bendera
# Maskyourneeds
# Eufloria
# Cansado
# BENG-BENG
# Beatrice
# Sepatu/wanita/pria/runing/anti/slip
# Mpek"
# Freshcare
# HIMALAYA
# Plossa
# Stimuno
# ORCHID
# Celluloss
# Silicone Case Premium Realme 7 7i 5i C15 C12 C17 C11 C2 C3 3 3i 5 6 C1 C3i 5 5S U1 X2 XT Q 6i 2 X2 5 PRO Narzo 20 PRO 10 10A 20A VIVO Y12 Y30 Y15 Y17 Y93 Y95 OPPO A31 2020 A9 A5 2020 A7 A5S A12 Cute Pearl Milk Tea Bear Soft Back Cover PopSocket
# BeauSlim
# Lazypod
# ZR-208
# Sajadah(Muka)Anak
# BERTAHAN
# Glulagen
# Masker
# Tricks
# Cansado
# Sendaljellybalance
# Bendera
# Gamis
# ZR-221
# beautyspray
# ZR-206
# Dermaroller
# Stimulant
# 1 61

# %%
max_len = 0
min_len = 10000
for t in titles_en_li:
    li = t.split(' ')
#     print(l)
    l = len(li)
    if l == 1:
        print(t)
    if l > 61:
        print(t)
    if l < min_len:
        min_len = l
    if l > max_len:
        max_len = l
print(min_len, max_len)
# Out:
# Caviplex
# [CHEERING]
# ?????????????????????
# Let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go!
# "Kylafood"
# Merries
# Let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go, let's go!
# SIGNATURE
# ...

# %%
df_train.loc[df_train.titles_en == '♪ To put in a baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby ♪ ♪ baby, baby, baby, baby, baby ♪ ♪ baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby']
# Out:
# Empty DataFrame
# Columns: [posting_id, image, image_phash, title, label_group, titles_en]
# Index: []

# %%
df_train.loc[df_train.titles_en == '♪ To put in a baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby, baby ♪ ♪ baby, baby ♪ ♪ baby, baby, baby, baby, baby ♪ ♪ baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby, baby']['title']
# Out:
# Series([], Name: title, dtype: object)

# %%
# from transformers import BertTokenizer, BertModel
# tokenizer=BertTokenizer.from_pretrained('bert-base-uncased')
# bert_model = BertModel.from_pretrained("bert-base-uncased")
# sentence=titles_en_li[0]
# #1.Tokenize the sequence:
# tokens=tokenizer.tokenize(sentence)
# print(tokens)
# print(type(tokens))

# %%
# tokens = ['[CLS]'] + tokens + ['[SEP]']
# print(" Tokens are \n {} ".format(tokens))

# %%
# T=61
# padded_tokens=tokens +['[PAD]' for _ in range(T-len(tokens))]
# print("Padded tokens are \n {} ".format(padded_tokens))
# attn_mask=[ 1 if token != '[PAD]' else 0 for token in padded_tokens  ]
# print("Attention Mask are \n {} ".format(attn_mask))

# %%
# seg_ids=[0 for _ in range(len(padded_tokens))]
# print("Segment Tokens are \n {}".format(seg_ids))

# %%
# sent_ids=tokenizer.convert_tokens_to_ids(padded_tokens)
# print("senetence idexes \n {} ".format(sent_ids))
# token_ids = torch.tensor(sent_ids).unsqueeze(0) 
# attn_mask = torch.tensor(attn_mask).unsqueeze(0) 
# seg_ids   = torch.tensor(seg_ids).unsqueeze(0)

# %%
# hidden_reps, cls_head = bert_model(token_ids, attention_mask = attn_mask,token_type_ids = seg_ids)
# print(type(hidden_reps))
# print(hidden_reps.shape ) #hidden states of each token in inout sequence 
# print(cls_head.shape ) #hidden states of each [cls]

# %%
from transformers import RobertaTokenizer, RobertaModel
import torch

tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
model = RobertaModel.from_pretrained('roberta-base')

inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
outputs = model(**inputs)
print(outputs)
last_hidden_states = outputs.last_hidden_state
# Out:
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[-0.0478,  0.0886, -0.0098,  ..., -0.0544, -0.0672, -0.0039],
#          [-0.0712,  0.0150, -0.1299,  ...,  0.0638,  0.0296, -0.0860],
#          [ 0.0906,  0.1437,  0.0828,  ...,  0.0509, -0.0320, -0.0490],
#          ...,
#          [ 0.0853,  0.2155,  0.0849,  ..., -0.1150,  0.0330, -0.0790],
#          [ 0.1679,  0.1288,  0.0065,  ...,  0.0367, -0.0631,  0.0276],
#          [-0.0436,  0.0892, -0.0389,  ..., -0.0957, -0.0744, -0.0284]]],
#        grad_fn=<NativeLayerNormBackward>), pooler_output=tensor([[-3.2083e-03, -2.1940e-01, -2.1088e-01, -7.6721e-02,  1.2052e-01,
#           2.0488e-01,  2.6070e-01, -8.4343e-02, -7.2521e-02, -1.7025e-01,
#           2.1089e-01, -2.1008e-02, -8.2022e-02,  1.0177e-01, -1.4424e-01,
#           4.9201e-01,  2.1202e-01, -4.5743e-01,  3.5993e-02, -1.5410e-02,
#          -2.7218e-01,  8.2779e-02,  4.7007e-01,  3.3553e-01,  1.1576e-01,
# ...

# %%
last_hidden_states.shape
# Out:
# torch.Size([1, 8, 768])

# %%
print(inputs)
# Out:
# {'input_ids': tensor([[    0, 31414,     6,   127,  2335,    16, 11962,     2]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1, 1, 1]])}

# %%
titles_en_li[0]
# Out:
# '♪ Paper Bag Victoria Secret ♪'

# %%
# from transformers import RobertaTokenizer, RobertaModel
# import torch
# tokenizer=RobertaTokenizer.from_pretrained('roberta-base')
# bert_model = RobertaModel.from_pretrained("roberta-base")
# sentence=titles_en_li[0]
# #1.Tokenize the sequence:
# tokens=tokenizer.tokenize(sentence)
# print(tokens)
# print(type(tokens))

# %%
# tokens = ['[CLS]'] + tokens + ['[SEP]']
# print(" Tokens are \n {} ".format(tokens))

# %%
# T=61
# padded_tokens=tokens +['[PAD]' for _ in range(T-len(tokens))]
# print("Padded tokens are \n {} ".format(padded_tokens))
# attn_mask=[ 1 if token != '[PAD]' else 0 for token in padded_tokens  ]
# print("Attention Mask are \n {} ".format(attn_mask))

# %%
# seg_ids=[0 for _ in range(len(padded_tokens))]
# print("Segment Tokens are \n {}".format(seg_ids))

# %%
# sent_ids=tokenizer.convert_tokens_to_ids(padded_tokens)
# print("senetence idexes \n {} ".format(sent_ids))
# token_ids = torch.tensor(sent_ids).unsqueeze(0) 
# attn_mask = torch.tensor(attn_mask).unsqueeze(0) 
# seg_ids   = torch.tensor(seg_ids).unsqueeze(0)

# %%
# hidden_reps, cls_head = bert_model(token_ids, attention_mask = attn_mask,token_type_ids = seg_ids)
# print(type(hidden_reps))
# print(hidden_reps.shape ) #hidden states of each token in inout sequence 
# print(cls_head.shape ) #hidden states of each [cls]

# %%
# hidden_reps
# Out:
# 'last_hidden_state'

# %%
# cls_head
# Out:
# 'pooler_output'

# %%
# output = bert_model(token_ids, attention_mask = attn_mask,token_type_ids = seg_ids)

# %%
# output.last_hidden_state.shape
# Out:
# torch.Size([1, 61, 768])

# %%
# output.pooler_output.shape
# Out:
# torch.Size([1, 768])

# %%
# from transformers import RobertaTokenizer, RobertaModel
# import torch
# tokenizer=RobertaTokenizer.from_pretrained('roberta-base')
# roberta_model = RobertaModel.from_pretrained("roberta-base")

# print(tokens)
# print(type(tokens))

# %%
from transformers import XLMRobertaTokenizer, XLMRobertaModel
xlmr_tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-base')
xlmr_model = XLMRobertaModel.from_pretrained('xlm-roberta-base')

T = 61
inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")
# padded_tokens=tokens +['[PAD]' for _ in range(T-len(inputs))]
outputs = model(**inputs)

last_hidden_states = outputs.last_hidden_state
last_hidden_states.shape
# Out:
# ...
# torch.Size([1, 8, 768])

# %%
def get_sentence_embedding(idx):
    sentence=titles_en_li[0]
    #1.Tokenize the sequence:
    tokens=tokenizer.tokenize(sentence)
    tokens = ['[CLS]'] + tokens + ['[SEP]']
    T=61
    padded_tokens=tokens +['[PAD]' for _ in range(T-len(tokens))]
    attn_mask=[ 1 if token != '[PAD]' else 0 for token in padded_tokens  ]
    seg_ids=[0 for _ in range(len(padded_tokens))]
    sent_ids=tokenizer.convert_tokens_to_ids(padded_tokens)
    
    token_ids = torch.tensor(sent_ids).unsqueeze(0) 
    attn_mask = torch.tensor(attn_mask).unsqueeze(0) 
    seg_ids   = torch.tensor(seg_ids).unsqueeze(0)
    
    output = bert_model(token_ids, attention_mask = attn_mask,token_type_ids = seg_ids)
    
    return output.last_hidden_state

# %%
import transformers as ppb

# %%
model_class, tokenizer_class, pretrained_weights = (ppb.XLMRobertaModel, ppb.XLMRobertaTokenizer, 'xlm-roberta-base')

# %%
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)

# %%
df = df_train[['title', 'label_group']]
batch_1 = df[:100]

# %%
tokenized = batch_1['title'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))

# %%
max_len = 61
for i in tokenized.values:
    if len(i) > max_len:
        max_len = len(i)

padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])

# %%
np.array(padded).shape
# Out:
# (100, 61)

# %%
attention_mask = np.where(padded != 0, 1, 0)
attention_mask.shape
# Out:
# (100, 61)

# %%
input_ids = torch.tensor(padded)  
attention_mask = torch.tensor(attention_mask)

with torch.no_grad():
    last_hidden_states = model(input_ids, attention_mask=attention_mask)

# %%
features = last_hidden_states[0][:,0,:].numpy()

# %%
features.shape
# Out:
# (100, 768)

# %%
df_train.shape
# Out:
# (34250, 6)

# %%
features
# Out:
# array([[ 0.14988948,  0.03903101, -0.07917569, ..., -0.01340169,
#         -0.02790985, -0.26609147],
#        [ 0.06986735,  0.07490286,  0.03756922, ..., -0.06743745,
#          0.0374313 , -0.02179043],
#        [ 0.14200725,  0.06136817,  0.05043354, ...,  0.08391855,
#          0.04539458, -0.03865747],
#        ...,
#        [ 0.13718432,  0.07813876, -0.01350252, ..., -0.10872778,
#          0.04775835,  0.11862719],
#        [ 0.16969696,  0.09188765, -0.01317044, ..., -0.14251497,
#         -0.0382593 , -0.08065216],
#        [ 0.22362138,  0.13516168,  0.08613466, ...,  0.05107655,
#         -0.05549702, -0.04318433]], dtype=float32)

# %%
embeddings = np.zeros((df_train.shape[0], 768))

# %%
embeddings.shape
# Out:
# (34250, 768)

# %%
# i

# %%
# for j in range(L):
#     embeddings[(i*L) + j] = features[j]

# %%
# df.tail()

# %%
import transformers as ppb
model_class, tokenizer_class, pretrained_weights = (ppb.XLMRobertaModel, ppb.XLMRobertaTokenizer, 'xlm-roberta-base')
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)

N = int(np.ceil(df_train.shape[0]/100))
L = 100
df = df_train[['title', 'label_group']]
for ii in tqdm(range(N)):
#     if ii  < N-1:
#         continue
    
    if ii != N-1:
        batch_1 = df[ii*L:(ii+1)*L]
    else:
        batch_1 = df[(N-1)*L:]
#     print(L, len(batch_1))
#     print(batch_1)
    tokenized = batch_1['title'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
    max_len = 61
    for i in tokenized.values:
        if len(i) > max_len:
            max_len = len(i)

    padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])
    attention_mask = np.where(padded != 0, 1, 0)
    input_ids = torch.tensor(padded)  
    attention_mask = torch.tensor(attention_mask)

    with torch.no_grad():
        last_hidden_states = model(input_ids, attention_mask=attention_mask)
    features = last_hidden_states[0][:,0,:].numpy()
    L1 = len(batch_1)
#     print(L1)
#     print(features)
    for j in range(L1):
        embeddings[(ii*L) + j] = features[j]

# %%
N
# Out:
# 343

# %%
embeddings.shape
# Out:
# (34250, 768)

# %%
for i in range(len(embeddings)):
    is_all_zero = np.all(embeddings[i] == 0)
    if is_all_zero:
        print(i)

# %%
np.save(CACHE_DIR+'/title_embeddings', embeddings)

# %%
# import transformers as ppb
# model_class, tokenizer_class, pretrained_weights = (ppb.XLMRobertaModel, ppb.XLMRobertaTokenizer, 'xlm-roberta-base')
# tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
# model = model_class.from_pretrained(pretrained_weights)

# %%
titles_1 = df_train.title.values
titles_1 = [s.replace('(', '') for s in titles_1]
titles_1 = [s.replace(')', '') for s in titles_1]
titles_1 = [s.replace('[', '') for s in titles_1]

import re
titles_1 = [s.replace('\\\\', '\\') for s in titles_1]
titles_1 = [re.sub(r'\\x[0-f]{2}',r'', s) for s in titles_1]
titles_1 = [s.replace('b"', '') for s in titles_1]
titles_1 = [s.replace('"', '') for s in titles_1]

# %%
# from transformers import AutoTokenizer, AutoConfig

import transformers as ppb
model_class, tokenizer_class, pretrained_weights = (ppb.XLMRobertaModel, ppb.XLMRobertaTokenizer, '/home/watts/Kaggle/kshop/xlm-roberta-base')
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)
embeddings = np.zeros((df_train.shape[0], 768))
# tokenizer = AutoTokenizer.from_pretrained('xlm-roberta-base')
# config = AutoConfig.from_pretrained('xlm-roberta-base')

# tokenizer.save_pretrained('../../')
# config.save_pretrained('YOURPATH')

# tokenizer = AutoTokenizer.from_pretrained('YOURPATH')

# %%
def get_text_embeddings(model, tokenizer, embeddings):
    N = int(np.ceil(df_train.shape[0]/100))
    L = 100
    df = titles_1
    model.eval()
    for ii in tqdm(range(N)):
    #     if ii != 0:
    #         continue
    #     if ii  < N-1:
    #         continue

        if ii != N-1:
            batch_1 = df[ii*L:(ii+1)*L]
        else:
            batch_1 = df[(N-1)*L:]
    #     print(L, len(batch_1))
    #     print(batch_1)
    #     tokenized = batch_1['title'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
        tokenized = [tokenizer.encode(x, add_special_tokens=True) for x in batch_1]
        max_len = 61
        for i in tokenized:
            if len(i) > max_len:
                max_len = len(i)

        padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized])
        attention_mask = np.where(padded != 0, 1, 0)
        input_ids = torch.tensor(padded)  
        attention_mask = torch.tensor(attention_mask)

        with torch.no_grad():
            last_hidden_states = model(input_ids, attention_mask=attention_mask)
        features = last_hidden_states[0][:,0,:].numpy()
        L1 = len(batch_1)
    #     print(L1)
    #     print(features)
        for j in range(L1):
            embeddings[(ii*L) + j] = features[j]
    
    return embeddings

# %%
import transformers as ppb
model_class, tokenizer_class, pretrained_weights = (ppb.BertModel, ppb.BertTokenizer, 'bert-base-uncased')
tokenizer = tokenizer_class.from_pretrained(pretrained_weights)
model = model_class.from_pretrained(pretrained_weights)
embeddings = np.zeros((df_train.shape[0], 768))

# %%
text_embeddings = get_text_embeddings(model, tokenizer, embeddings)
# Out:
#   0%|          | 0/343 [00:00<?, ?it/s]

# %%
# N = int(np.ceil(df_train.shape[0]/100))
# L = 100
# df = df_train[['title', 'label_group']]
# model.eval()
# for ii in tqdm(range(N)):
# #     if ii != 0:
# #         continue
# #     if ii  < N-1:
# #         continue
    
#     if ii != N-1:
#         batch_1 = df.iloc[ii*L:(ii+1)*L]
#     else:
#         batch_1 = df.iloc[(N-1)*L:]
# #     print(L, len(batch_1))
# #     print(batch_1)
#     tokenized = batch_1['title'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
#     max_len = 61
#     for i in tokenized.values:
#         if len(i) > max_len:
#             max_len = len(i)

#     padded = np.array([i + [0]*(max_len-len(i)) for i in tokenized.values])
#     attention_mask = np.where(padded != 0, 1, 0)
#     input_ids = torch.tensor(padded)  
#     attention_mask = torch.tensor(attention_mask)

#     with torch.no_grad():
#         last_hidden_states = model(input_ids, attention_mask=attention_mask)
#     features = last_hidden_states[0][:,0,:].numpy()
#     L1 = len(batch_1)
# #     print(L1)
# #     print(features)
#     for j in range(L1):
#         embeddings[(ii*L) + j] = features[j]

# %%
df[0:10]
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
# 5  train_2464356923  0013e7355ffc5ff8fb1ccad3e42d92fe.jpg  bbd097a7870f4a50
# 6  train_1802986387  00144a49c56599d45354a1c28104c039.jpg  f815c9bb833ab4c8
# 7  train_1806152124  0014f61389cbaa687a58e38a97b6383d.jpg  eea7e1c0c04da33d
# 8    train_86570404  0019a3c6755a194cb2e2c12bfc63972e.jpg  ea9af4f483249972
# 9   train_831680791  001be52b2beec40ddc1d2d7fc7a68f08.jpg  e1ce953d1a70618f
#
#                                                title  label_group  \
# ...

# %%
embeddings[0].shape
# Out:
# (768,)

# %%
embeddings[0]
# Out:
# array([-1.32334113e-01,  6.20016828e-02, -9.88943204e-02,  1.44214332e-01,
#        -1.49815157e-01, -7.21328631e-02,  2.78711617e-01,  1.07595325e-02,
#        -2.55614638e-01,  6.04621246e-02,  2.52591036e-02, -1.69300959e-01,
#         1.68510750e-01,  4.93968755e-01,  1.67942628e-01, -5.50701544e-02,
#        -3.70564342e-01,  4.37890887e-01,  4.12424117e-01, -1.05104245e-01,
#         2.05251560e-01, -2.18272999e-01, -3.84597450e-01, -9.18444917e-02,
#         1.70880109e-01,  1.04353726e-01,  9.05390009e-02,  1.29835635e-01,
#         2.56501198e-01,  1.43200651e-01,  1.37166589e-01, -7.39902258e-02,
#         1.30214207e-02, -9.64481458e-02,  4.21607047e-01, -2.80146718e-01,
#         1.20349072e-01, -3.19339007e-01, -3.18633802e-02,  1.95992892e-04,
#         2.02420890e-01,  4.46815081e-02,  2.60645092e-01, -1.70017377e-01,
#         1.05962142e-01, -2.77918667e-01, -1.87112975e+00, -6.95032701e-02,
# ...

# %%
embeddings[0]
# Out:
# array([ 1.49889484e-01,  3.90310064e-02, -7.91756883e-02,  9.87221766e-03,
#        -3.35577354e-02,  1.09050944e-01,  1.46973161e-02, -1.70402125e-01,
#         3.06368530e-01, -1.83304593e-01, -3.53885815e-03,  3.71795706e-02,
#         1.60214707e-01, -1.51718080e-01,  2.09579796e-01, -7.45534301e-02,
#        -1.56408235e-01, -5.78343458e-02,  2.29154453e-01,  1.49746582e-01,
#        -1.15051396e-01, -8.92264843e-02,  2.07638770e-01, -1.19207248e-01,
#         1.79906487e-01,  1.30726723e-02,  1.76909361e-02,  8.01893249e-02,
#         1.34021431e-01,  2.27965206e-01,  7.61487111e-02,  5.64484857e-02,
#        -3.85006331e-02, -6.11651354e-02,  3.40238154e-01,  6.80488795e-02,
#        -1.73929691e-01, -6.77010193e-02,  1.19512945e-01,  2.39029661e-01,
#        -3.68947089e-02,  1.00008532e-01,  9.72544774e-02, -1.60638854e-01,
#         1.07732892e-01, -1.74121529e-01, -8.30326825e-02,  1.23788984e-02,
# ...

# %%
embeddings[1]
# Out:
# array([ 6.98673502e-02,  7.49028623e-02,  3.75692248e-02, -5.53055108e-02,
#         1.22777000e-01, -2.02500243e-02,  2.68963743e-02, -6.01531565e-02,
#         1.06544629e-01, -1.87689945e-01,  3.66601795e-02,  1.01040274e-01,
#         5.23982309e-02, -5.22936694e-02,  9.49079245e-02,  1.11324474e-01,
#        -3.69176939e-02, -6.62101880e-02,  1.47456780e-01,  1.22416824e-01,
#         1.14558816e-01,  3.42317810e-03,  1.17608160e-01, -4.23058234e-02,
#         3.08075882e-02, -2.56489497e-02, -2.57752687e-02, -4.58000004e-02,
#         7.33892098e-02,  1.14671506e-01,  9.44672897e-02,  4.62188050e-02,
#        -9.74215567e-02,  2.39180118e-01,  1.10605806e-01, -3.63040082e-02,
#        -1.54062077e-01, -5.24601750e-02,  4.09800224e-02,  8.89214724e-02,
#         6.16160147e-02,  1.66238114e-01,  8.21959004e-02, -6.86467364e-02,
#         1.08047463e-01, -1.12905249e-01, -6.42772391e-02, -1.30687237e-01,
# ...

# %%
GET_CV = True
CHECK_SUB = False
import cudf, cuml, cupy

from cuml import PCA
from cuml.neighbors import NearestNeighbors
# from sklearn.neighbors import NearestNeighbors

# %%
# Function to get our f1 score
def f1_score(y_true, y_pred):
    y_true = y_true.apply(lambda x: set(x.split()))
    y_pred = y_pred.apply(lambda x: set(x.split()))
    intersection = np.array([len(x[0] & x[1]) for x in zip(y_true, y_pred)])
    len_y_pred = y_pred.apply(lambda x: len(x)).values
    len_y_true = y_true.apply(lambda x: len(x)).values
    f1 = 2 * intersection / (len_y_pred + len_y_true)
    return f1

# Function to combine predictions
def combine_predictions(row):
    x = np.concatenate([row['image_predictions'], row['text_predictions'], row['oof_text']])
    return ' '.join( np.unique(x) )

# Function to read out dataset
def read_dataset():
    if GET_CV:
        df = pd.read_csv('../data/train.csv')
        tmp = df.groupby(['label_group'])['posting_id'].unique().to_dict()
        df['matches'] = df['label_group'].map(tmp)
        df['matches'] = df['matches'].apply(lambda x: ' '.join(x))
        if CHECK_SUB:
            df = pd.concat([df, df], axis = 0)
            df.reset_index(drop = True, inplace = True)
#         df_cu = cudf.DataFrame(df)
        image_paths = '../data/train_images/' + df['image']
    else:
        df = pd.read_csv('../data/test.csv')
#         df_cu = cudf.DataFrame(df)
        image_paths = '../data/test_images/' + df['image']
    
    return df, image_paths
#     return df, df_cu, image_paths

# %%
# df = df_train.copy()

# %%
import gc
df, image_paths = read_dataset()

# %%
df.head()
# Out:
#          posting_id                                 image       image_phash  \
# 0   train_129225211  0000a68812bc7e98c42888dfb1c07da0.jpg  94974f937d4c2433
# 1  train_3386243561  00039780dfc94d01db8676fe789ecd05.jpg  af3f9460c2838f0f
# 2  train_2288590299  000a190fdd715a2a36faed16e2c65df7.jpg  b94cb00ed3e50f78
# 3  train_2406599165  00117e4fc239b1b641ff08340b429633.jpg  8514fc58eafea283
# 4  train_3369186413  00136d1cf4edede0203f32f05f660588.jpg  a6f319f924ad708c
#
#                                                title  label_group  \
# 0                          Paper Bag Victoria Secret    249114794
# 1  Double Tape 3M VHB 12 mm x 4,5 m ORIGINAL / DO...   2937985045
# 2        Maling TTS Canned Pork Luncheon Meat 397 gr   2395904891
# 3  Daster Batik Lengan pendek - Motif Acak / Camp...   4093212188
# 4                  Nescafe \xc3\x89clair Latte 220ml   3648931069
#
#                              matches
# 0   train_129225211 train_2278313361
# ...

# %%
# Function to get 50 nearest neighbors of each image and apply a distance threshold to maximize cv
def get_neighbors(df, embeddings, KNN = 50, image = True):
    model = NearestNeighbors(n_neighbors = KNN)
    model.fit(embeddings)
    distances, indices = model.kneighbors(embeddings)
    print(distances, np.max(distances), np.min(distances))
    
    # Iterate through different thresholds to maximize cv, run this in interactive mode, then replace else clause with a solid threshold
    if GET_CV:
        if image:
            thresholds = list(np.arange(3.0, 5.0, 0.1))
        else:
#             thresholds = list(np.arange(0, 10, 1))
            thresholds = list(np.arange(0.0, np.ceil(np.max(distances)), 0.1))
        scores = []
        for threshold in thresholds:
            predictions = []
            for k in range(embeddings.shape[0]):
                idx = np.where(distances[k,] < threshold)[0]
                ids = indices[k,idx]
                posting_ids = ' '.join(df['posting_id'].iloc[ids].values)
                predictions.append(posting_ids)
            df['pred_matches'] = predictions
            df['f1'] = f1_score(df['matches'], df['pred_matches'])
            score = df['f1'].mean()
            print(f'Our f1 score for threshold {threshold} is {score}')
            scores.append(score)
        thresholds_scores = pd.DataFrame({'thresholds': thresholds, 'scores': scores})
        max_score = thresholds_scores[thresholds_scores['scores'] == thresholds_scores['scores'].max()]
        best_threshold = max_score['thresholds'].values[0]
        best_score = max_score['scores'].values[0]
        print(f'Our best score is {best_score} and has a threshold {best_threshold}')
        
        # Use threshold
        predictions = []
        for k in range(embeddings.shape[0]):
            # Because we are predicting the test set that have 70K images and different label groups, confidence should be smaller
            if image:
                idx = np.where(distances[k,] < 3.6)[0]
            else:
                idx = np.where(distances[k,] < 20.0)[0]
            ids = indices[k,idx]
            posting_ids = df['posting_id'].iloc[ids].values
            predictions.append(posting_ids)
    
    # Because we are predicting the test set that have 70K images and different label groups, confidence should be smaller
    else:
        predictions = []
        for k in tqdm(range(embeddings.shape[0])):
            if image:
                idx = np.where(distances[k,] < 3.6)[0]
            else:
                idx = np.where(distances[k,] < 20.0)[0]
            ids = indices[k,idx]
            posting_ids = df['posting_id'].iloc[ids].values
            predictions.append(posting_ids)
        
    del model, distances, indices
    gc.collect()
    return df, predictions

# %%
df, text_predictions = get_neighbors(df, embeddings, KNN = 100, image = False)
# Out:
# Our f1 score for threshold 15 is 0.03775810368608181
# Our f1 score for threshold 16 is 0.03775810368608181
# Our f1 score for threshold 17 is 0.03775810368608181
# Our f1 score for threshold 18 is 0.03775810368608181
# Our f1 score for threshold 19 is 0.03775810368608181
# Our f1 score for threshold 20 is 0.03775810368608181
# Our f1 score for threshold 21 is 0.03775810368608181
# Our f1 score for threshold 22 is 0.03775810368608181
# Our f1 score for threshold 23 is 0.03775810368608181
# Our f1 score for threshold 24 is 0.03775810368608181
# Our f1 score for threshold 25 is 0.03775810368608181
# Our f1 score for threshold 26 is 0.03775810368608181
# Our f1 score for threshold 27 is 0.03775810368608181
# Our f1 score for threshold 28 is 0.03775810368608181
# Our f1 score for threshold 29 is 0.03775810368608181
# Our f1 score for threshold 30 is 0.03775810368608181
# Our f1 score for threshold 31 is 0.03775810368608181
# Our f1 score for threshold 32 is 0.03775810368608181
# ...

# %%
df, text_predictions = get_neighbors(df, embeddings, KNN = 100, image = False)

# xml-roberta-base: Our f1 score for threshold 1.2000000000000002 is 0.49125461681317695
# bert-base_uncased: Our f1 score for threshold 3.6 is 0.5095938137032459
# Out:
# [[1.3531648e-02 1.3531648e-02 4.2787528e+00 ... 4.7751093e+00
#   4.7814956e+00 4.7840209e+00]
#  [5.5242712e-03 5.3979716e+00 5.4517970e+00 ... 6.8368001e+00
#   6.8399119e+00 6.8598309e+00]
#  [0.0000000e+00 5.2621179e+00 5.6331730e+00 ... 6.5759401e+00
#   6.5770259e+00 6.5793200e+00]
#  ...
#  [0.0000000e+00 4.2911501e+00 4.3525691e+00 ... 5.9083710e+00
#   5.9099422e+00 5.9172196e+00]
#  [5.5242712e-03 4.3787093e+00 4.6360803e+00 ... 5.2944865e+00
#   5.2950149e+00 5.2978401e+00]
#  [1.8321937e-02 5.9955249e+00 6.1194344e+00 ... 6.7899384e+00
#   6.7910995e+00 6.7931170e+00]] 12.532712 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.48406620681447626
# Our f1 score for threshold 0.2 is 0.48406620681447626
# Our f1 score for threshold 0.30000000000000004 is 0.48406620681447626
# Our f1 score for threshold 0.4 is 0.4840817785906321
# Our f1 score for threshold 0.5 is 0.4841221236470355
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('distiluse-base-multilingual-cased-v2')
embeddings = np.zeros((df_train.shape[0], 512))

# %%
sentences = titles_1[:10]

# %%
sentence_embeddings = model.encode(sentences)

# %%
sentence_embeddings.shape
# Out:
# (10, 512)

# %%
def get_text_embeddings2(model, embeddings):
    N = int(np.ceil(df_train.shape[0]/100))
    L = 100
    df = titles_1
    model.eval()
    for ii in tqdm(range(N)):
    #     if ii != 0:
    #         continue
    #     if ii  < N-1:
    #         continue

        if ii != N-1:
            batch_1 = df[ii*L:(ii+1)*L]
        else:
            batch_1 = df[(N-1)*L:]
    #     print(L, len(batch_1))
    #     print(batch_1)
    #     tokenized = batch_1['title'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
        

       
        features = model.encode(batch_1)
        L1 = len(batch_1)
    #     print(L1)
    #     print(features)
        for j in range(L1):
            embeddings[(ii*L) + j] = features[j]
    
    return embeddings

# %%
text_embeddings = get_text_embeddings2(model, embeddings)
df, text_predictions = get_neighbors(df, embeddings, KNN = 100, image = False)
# distiluse-base-multilingual-cased-v2: Our f1 score for threshold 0.4 is 0.5170136399261481
# Out:
# [[4.8828125e-04 7.5790185e-01 8.7771934e-01 ... 9.9788767e-01
#   9.9801445e-01 9.9802870e-01]
#  [4.8828125e-04 3.6364302e-01 5.5472982e-01 ... 8.6293668e-01
#   8.6294723e-01 8.6350912e-01]
#  [5.9801998e-04 3.4843075e-01 6.6366553e-01 ... 7.9904771e-01
#   7.9913104e-01 8.0085295e-01]
#  ...
#  [0.0000000e+00 5.7497394e-01 7.0065123e-01 ... 9.0157568e-01
#   9.0185773e-01 9.0200508e-01]
#  [0.0000000e+00 3.4031183e-01 4.4737995e-01 ... 7.3623192e-01
#   7.3628300e-01 7.3716766e-01]
#  [0.0000000e+00 4.9318120e-01 5.0239563e-01 ... 5.9539431e-01
#   5.9543210e-01 5.9554321e-01]] 1.1147618 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.4792571800431325
# Our f1 score for threshold 0.2 is 0.4898998540573019
# Our f1 score for threshold 0.30000000000000004 is 0.5059627556043288
# Our f1 score for threshold 0.4 is 0.5170136399261481
# Our f1 score for threshold 0.5 is 0.5156873049216649
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('paraphrase-xlm-r-multilingual-v1')
sentences = titles_1[:5]
sentence_embeddings = model.encode(sentences)
embeddings = np.zeros((df_train.shape[0], sentence_embeddings.shape[1]))
df, _ = read_dataset()
text_embeddings = get_text_embeddings2(model, embeddings)
df, text_predictions = get_neighbors(df, embeddings, KNN = 100, image = False)
# Our f1 score for threshold 3.0 is 0.5375538273101342
# Out:
#   0%|          | 0/343 [00:00<?, ?it/s]
# [[6.1763236e-03 5.5575442e+00 5.5695815e+00 ... 6.2158151e+00
#   6.2159133e+00 6.2172775e+00]
#  [0.0000000e+00 2.9131787e+00 3.3321021e+00 ... 5.5784559e+00
#   5.5823846e+00 5.5834923e+00]
#  [0.0000000e+00 2.8265626e+00 5.2514143e+00 ... 5.7177253e+00
#   5.7200136e+00 5.7210693e+00]
#  ...
#  [0.0000000e+00 3.3696823e+00 3.8964059e+00 ... 5.3138666e+00
#   5.3143744e+00 5.3164115e+00]
#  [4.7841598e-03 2.8367016e+00 3.7058752e+00 ... 4.4275193e+00
#   4.4297686e+00 4.4299984e+00]
#  [4.3673203e-03 3.5050867e+00 3.7565625e+00 ... 4.2294121e+00
#   4.2318435e+00 4.2330303e+00]] 7.790815 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.4764084404972778
# Our f1 score for threshold 0.2 is 0.47643731316556653
# Our f1 score for threshold 0.30000000000000004 is 0.4764742961339364
# Our f1 score for threshold 0.4 is 0.476658129035371
# Our f1 score for threshold 0.5 is 0.4769270941088744
# ...

# %%
models = [
    'paraphrase-distilroberta-base-v1',
    'paraphrase-xlm-r-multilingual-v1',
    'stsb-roberta-large',
    'stsb-roberta-base',
    'stsb-bert-large',
    'stsb-distilbert-base',
    'stsb-bert-base',
    'paraphrase-xlm-r-multilingual-v1',
    'paraphrase-distilroberta-base-v1',
    'nli-bert-large',
    'nli-distilbert-base',
    'nli-roberta-large',
    'nli-bert-large-max-pooling',
    'nli-bert-large-cls-pooling',
    'nli-distilbert-base-max-pooling',
    'nli-roberta-base',
    'nli-bert-base-max-pooling',
    'nli-bert-base',
    'nli-bert-base-cls-pooling',
    'average_word_embeddings_glove.6B.300d',
    'average_word_embeddings_komninos',
    'average_word_embeddings_levy_dependency',
    'average_word_embeddings_glove.840B.300d',
    'quora-distilbert-base',
    'quora-distilbert-multilingual',
    'msmarco-distilbert-base-v3',
    'msmarco-distilbert-base-dot-prod-v3',
    'msmarco-roberta-base-ance-fristp',
    'nq-distilbert-base-v1',
    'facebook-dpr-ctx_encoder-single-nq-base',
    'facebook-dpr-question_encoder-single-nq-base',
    'facebook-dpr-ctx_encoder-multiset-base',
    'facebook-dpr-question_encoder-multiset-base',
    'distiluse-base-multilingual-cased-v1',
    'distiluse-base-multilingual-cased-v2',
    'paraphrase-xlm-r-multilingual-v1',
    'stsb-xlm-r-multilingual',
    'allenai-specter',
    'average_word_embeddings_glove.6B.300d',
    'average_word_embeddings_komninos',
    'average_word_embeddings_levy_dependency',
    'average_word_embeddings_glove.840B.300d'
]

# %%
from sentence_transformers import SentenceTransformer
for m in models:
    model = SentenceTransformer(m)
    sentences = titles_1[:5]
    sentence_embeddings = model.encode(sentences)
    embeddings = np.zeros((df_train.shape[0], sentence_embeddings.shape[1]))
    df, _ = read_dataset()
    text_embeddings = get_text_embeddings2(model, embeddings)
    df, text_predictions = get_neighbors(df, embeddings, KNN = 100, image = False)
    print(m)

# msmarco-distilbert-base-v3: Our best score is 0.6210519837177707 and has a threshold 8.8
# msmarco-distilbert-base-dot-prod-v3: Our best score is 0.6261519622106636 and has a threshold 5.9
#stsb-roberta-large: Our best score is 0.5922522401523052 and has a threshold 16.400000000000002
*# stsb-roberta-base: Our best score is 0.5923117668109386 and has a threshold 10.200000000000001
*# stsb-distilbert-base: Our best score is 0.6066519618983829 and has a threshold 8.5
*# stsb-bert-base: Our best score is 0.5955371449284111 and has a threshold 8.0
# msmarco-roberta-base-ance-fristp: Our best score is 0.6040891398327813 and has a threshold 3.2
# facebook-dpr-question_encoder-single-nq-base: Our best score is 0.6034463956992172 and has a threshold 3.7
*# facebook-dpr-question_encoder-multiset-base: Our best score is 0.6059236437393868 and has a threshold 4.3
# Out:
#   0%|          | 0.00/306M [00:00<?, ?B/s]
#   0%|          | 0/343 [00:00<?, ?it/s]
# [[7.8125000e-03 7.0799742e+00 7.1328454e+00 ... 7.7049365e+00
#   7.7102137e+00 7.7102137e+00]
#  [0.0000000e+00 4.2663317e+00 4.6403651e+00 ... 6.9581633e+00
#   6.9600081e+00 6.9668407e+00]
#  [2.7621356e-03 4.2560611e+00 6.7139544e+00 ... 7.7440863e+00
#   7.7471991e+00 7.7498536e+00]
#  ...
#  [0.0000000e+00 4.4798303e+00 5.0539913e+00 ... 6.6983042e+00
#   6.7000628e+00 6.7009974e+00]
#  [6.7658238e-03 3.8531101e+00 5.7533789e+00 ... 7.4672208e+00
#   7.4680285e+00 7.4684014e+00]
#  [0.0000000e+00 7.1446543e+00 7.3657393e+00 ... 8.2458773e+00
#   8.2472544e+00 8.2484865e+00]] 11.165958 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.4759934557907602
# Our f1 score for threshold 0.2 is 0.4759934557907602
# Our f1 score for threshold 0.30000000000000004 is 0.4759934557907602
# Our f1 score for threshold 0.4 is 0.4759934557907602
# ...

# %%
from transformers import AutoTokenizer, AutoModel
import torch


#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
    sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
    return sum_embeddings / sum_mask



# Queries we want embeddings for
queries = ['What is the capital of France?', 'How many people live in New York City?']

# Passages that provide answers
passages = ['Paris is the capital of France', 'New York City is the most populous city in the United States, with an estimated 8,336,817 people living in the city, according to U.S. Census estimates dating July 1, 2019']

#Load AutoModel from huggingface model repository
tokenizer = AutoTokenizer.from_pretrained("/home/watts/lal/Kaggle/kshop/msmarco-distilbert-base-dot-prod-v3")
model = AutoModel.from_pretrained("/home/watts/lal/Kaggle/kshop/msmarco-distilbert-base-dot-prod-v3")

def compute_embeddings(sentences):
    #Tokenize sentences
    encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

    #Compute query embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)

    #Perform pooling. In this case, mean pooling
    return mean_pooling(model_output, encoded_input['attention_mask'])

# %%
query_embeddings = compute_embeddings(queries)
passage_embeddings = compute_embeddings(passages)

# %%
query_embeddings.shape, passage_embeddings.shape
# Out:
# (torch.Size([2, 768]), torch.Size([2, 768]))

# %%
def get_text_embeddings3(embeddings):
    N = int(np.ceil(df_train.shape[0]/100))
    L = 100
    
    for ii in tqdm(range(N)):
    #     if ii != 0:
    #         continue
    #     if ii  < N-1:
    #         continue

        if ii != N-1:
            batch_1 = titles_1[ii*L:(ii+1)*L]
        else:
            batch_1 = titles_1[(N-1)*L:]
        
        features = compute_embeddings(batch_1).numpy()
        L1 = len(batch_1)
    #     print(L1)
    #     print(features)
        for j in range(L1):
            embeddings[(ii*L) + j] = features[j]
    
    return embeddings

# %%
embeddings = np.zeros((df_train.shape[0], 768))
text_embeddings = get_text_embeddings3(embeddings)
# Out:
#   0%|          | 0/343 [00:00<?, ?it/s]

# %%
text_embeddings.shape
# Out:
# (34250, 768)

# %%
import gc
df, image_paths = read_dataset()

# %%
df, text_predictions = get_neighbors(df, text_embeddings, KNN = 100, image = False)
# Out:
# [[0.00000000e+00 0.00000000e+00 1.33159666e+01 ... 1.57770052e+01
#   1.57795897e+01 1.57819633e+01]
#  [0.00000000e+00 8.35950851e+00 8.35950851e+00 ... 1.38077650e+01
#   1.38117371e+01 1.38151026e+01]
#  [0.00000000e+00 7.18264675e+00 1.32472754e+01 ... 1.48089476e+01
#   1.48190517e+01 1.48190517e+01]
#  ...
#  [9.56831966e-03 9.00601482e+00 9.77843571e+00 ... 1.35838127e+01
#   1.35903416e+01 1.36001673e+01]
#  [5.52427117e-03 6.48882341e+00 7.89469719e+00 ... 1.27688236e+01
#   1.27717562e+01 1.27738371e+01]
#  [0.00000000e+00 1.07818794e+01 1.28756409e+01 ... 1.44479885e+01
#   1.44479885e+01 1.44505024e+01]] 16.587835 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.4837609333431556
# Our f1 score for threshold 0.2 is 0.4837609333431556
# Our f1 score for threshold 0.30000000000000004 is 0.4837609333431556
# Our f1 score for threshold 0.4 is 0.4837609333431556
# Our f1 score for threshold 0.5 is 0.4837541206910875
# ...

# %%
tokenizer = AutoTokenizer.from_pretrained("/home/watts/lal/Kaggle/kshop/bert-base-uncased")
model = AutoModel.from_pretrained("/home/watts/lal/Kaggle/kshop/bert-base-uncased")
embeddings = np.zeros((df_train.shape[0], 768))
text_embeddings = get_text_embeddings3(embeddings)
df, image_paths = read_dataset()
df, text_predictions = get_neighbors(df, text_embeddings, KNN = 100, image = False)
# Out:
#   0%|          | 0/343 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [[0.0000000e+00 0.0000000e+00 5.6034808e+00 ... 6.3261237e+00
#   6.3261237e+00 6.3261237e+00]
#  [1.1048542e-02 3.5158455e+00 3.5158455e+00 ... 5.6141243e+00
#   5.6160131e+00 5.6175771e+00]
#  [3.9062500e-03 2.8820584e+00 4.9826918e+00 ... 6.0212402e+00
#   6.0214806e+00 6.0246415e+00]
#  ...
#  [1.0334966e-02 3.2405517e+00 3.3453331e+00 ... 5.2963824e+00
#   5.2965097e+00 5.3004217e+00]
#  [3.9062500e-03 3.5196614e+00 3.9482071e+00 ... 4.4972968e+00
#   4.4981174e+00 4.5011840e+00]
#  [8.7346407e-03 4.6404772e+00 4.8465528e+00 ... 5.3137321e+00
#   5.3145452e+00 5.3184705e+00]] 11.18184 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.4837609333431556
# Our f1 score for threshold 0.2 is 0.4837609333431556
# ...

# %%
from transformers import DistilBertTokenizer, DistilBertModel

# model_name='cahya/distilbert-base-indonesian'
model_name = '/home/watts/lal/Kaggle/kshop/distilbert-base-indonesian'
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertModel.from_pretrained(model_name)
text = "Silakan diganti dengan text apa saja."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)

# %%
output.last_hidden_state.shape
# Out:
# torch.Size([1, 10, 768])

# %%
output.hidden_states[0].shape
# Out:
# torch.Size([1, 10, 768])

# %%
output.last_hidden_state[:,0,:].shape
# Out:
# torch.Size([1, 768])

# %%
def get_text_embeddings4(model, tokenizer, embeddings):
    N = int(np.ceil(df_train.shape[0]/100))
    L = 100
    df = titles_1
    max_len = 70
    model.eval()
    for ii in tqdm(range(N)):
    #     if ii != 0:
    #         continue
    #     if ii  < N-1:
    #         continue

        if ii != N-1:
            batch_1 = df[ii*L:(ii+1)*L]
        else:
            batch_1 = df[(N-1)*L:]
    #     print(L, len(batch_1))
    #     print(batch_1)
    #     tokenized = batch_1['title'].apply((lambda x: tokenizer.encode(x, add_special_tokens=True)))
        tokenized = [tokenizer(x, padding=True, truncation=True, max_length=70, return_tensors='pt') for x in batch_1]
#         tokenized = [tokenizer.encode(x, add_special_tokens=True) for x in batch_1]
        
        for j, token in enumerate(tokenized):
            with torch.no_grad():
                output = model(**token)
                features = output.last_hidden_state[:,0,:].numpy()
#         L1 = len(batch_1)
    #     print(L1)
    #     print(features)
#         for j in range(L1):
                embeddings[(ii*L) + j] = features
    
    return embeddings

# %%
embeddings = np.zeros((df_train.shape[0], 768))
text_embeddings = get_text_embeddings4(model, tokenizer, embeddings)
# Out:
#   0%|          | 0/343 [00:00<?, ?it/s]

# %%
for i in range(len(embeddings)):
    is_all_zero = np.all(embeddings[i] == 0)
    if is_all_zero:
        print(i)

# %%
import gc
df, image_paths = read_dataset()
df, text_predictions = get_neighbors(df, text_embeddings, KNN = 100, image = False)
# Out:
# [[ 0.01104854  0.01104854  6.2790394  ...  8.642278    8.64501
#    8.646591  ]
#  [ 0.          4.5322666   4.7014375  ...  9.413856    9.41426
#    9.41615   ]
#  [ 0.01104854  7.516462    8.171229   ...  9.131369    9.141293
#    9.142637  ]
#  ...
#  [ 0.015625    6.188146    6.4043393  ...  8.809997    8.810023
#    8.811315  ]
#  [ 0.03314563  4.7394648   5.854988   ... 10.281414   10.287232
#   10.287787  ]
#  [ 0.01104854  7.235632    7.6378446  ...  8.701988    8.70269
#    8.703111  ]] 14.070132 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.4837554183391004
# Our f1 score for threshold 0.2 is 0.4837554183391004
# Our f1 score for threshold 0.30000000000000004 is 0.4837554183391004
# Our f1 score for threshold 0.4 is 0.4837611187214432
# Our f1 score for threshold 0.5 is 0.48378572768911776
# Our f1 score for threshold 0.6000000000000001 is 0.48380227691442623
# Our f1 score for threshold 0.7000000000000001 is 0.48393784742663903
# ...

# %%
from transformers import BertTokenizer, BertModel

# model_name='cahya/distilbert-base-indonesian'
model_name = '/home/watts/lal/Kaggle/kshop/bert-base-indonesian-522M'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
text = "Silakan diganti dengan text apa saja."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
print(output.last_hidden_state[:,0,:].shape)
embeddings = np.zeros((df_train.shape[0], 768))
text_embeddings = get_text_embeddings4(model, tokenizer, embeddings)

for i in range(len(embeddings)):
    is_all_zero = np.all(embeddings[i] == 0)
    if is_all_zero:
        print(i)
        
df, image_paths = read_dataset()
df, text_predictions = get_neighbors(df, text_embeddings, KNN = 100, image = False)
# Out:
# torch.Size([1, 768])
#   0%|          | 0/343 [00:00<?, ?it/s]
# [[ 0.          0.          7.909615   ... 10.269697   10.277063
#   10.279425  ]
#  [ 0.          7.013785    7.013785   ... 10.357463   10.361534
#   10.361534  ]
#  [ 0.01913664  7.414849   10.091324   ... 11.158095   11.159034
#   11.160013  ]
#  ...
#  [ 0.          5.652272    5.7866473  ...  8.949459    8.950735
#    8.951188  ]
#  [ 0.          6.286757    7.0873027  ... 10.075929   10.079524
#   10.085542  ]
#  [ 0.03493856  8.291426    8.481745   ...  9.968415    9.968991
#    9.973386  ]] 14.0880575 0.0
# Our f1 score for threshold 0.0 is 0.0
# Our f1 score for threshold 0.1 is 0.4837554183391004
# Our f1 score for threshold 0.2 is 0.4837554183391004
# Our f1 score for threshold 0.30000000000000004 is 0.4837554183391004
# Our f1 score for threshold 0.4 is 0.4837554183391004
# Our f1 score for threshold 0.5 is 0.4837554183391004
# Our f1 score for threshold 0.6000000000000001 is 0.4837701559129621
# ...
